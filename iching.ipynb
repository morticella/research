# %% [markdown]
# # PRE INSTALL

# %%
import datapackage
import pandas as pd

# %% [markdown]
#  ## Import

# %%
# generate random integer values
from random import seed
from random import randint

# %%
data_url = './dataset/vix-daily.csv'

data = pd.read_csv(data_url)


df = pd.DataFrame(data)
print(df)
# Out:
#             Date  VIX Open  VIX High  VIX Low  VIX Close
# 0     2004-01-02     17.96     18.68    17.54      18.22
# 1     2004-01-05     18.45     18.49    17.44      17.49
# 2     2004-01-06     17.66     17.67    16.19      16.73
# 3     2004-01-07     16.72     16.75    15.50      15.50
# 4     2004-01-08     15.42     15.68    15.32      15.61
# 5     2004-01-09     16.15     16.88    15.57      16.75
# 6     2004-01-12     17.32     17.46    16.79      16.82
# 7     2004-01-13     16.60     18.33    16.53      18.04
# 8     2004-01-14     17.29     17.30    16.40      16.75
# 9     2004-01-15     17.07     17.31    15.49      15.56
# 10    2004-01-16     15.40     15.44    14.90      15.00
# 11    2004-01-20     15.77     16.13    15.09      15.21
# 12    2004-01-21     15.63     15.63    14.24      14.34
# 13    2004-01-22     14.20     14.87    14.01      14.71
# 14    2004-01-23     14.73     15.05    14.56      14.84
# ...

# %%
def iching():
    result = 0
    for index in range(6):
        line = 0
        for _ in range(3):
            value = randint(2, 3)
            line = line + value
            if index == 0:
                line1 = line
            if index == 1:
                line2 = line
            if index == 2:
                line3 = line
            if index == 3:
                line4 = line
            if index == 4:
                line5 = line
            if index == 5:
                line6 = line
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 1
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 2
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 3
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 4
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 5
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 6
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 7
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 8
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 9
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 10
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 11
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 12 
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 13
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 14  
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 15
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 16
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 17
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 18
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 19
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 20
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 21
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 22
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 23
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 24
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 25
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 26
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 27
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 28
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 29
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 30
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 31
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 32
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 33
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 34
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 35
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 36
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 37
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 38
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 39
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 40
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 41
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 42
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 43
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 44
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 45
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 46
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 47
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 48
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 49
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 50
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 51
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 52
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 53
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 54
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 55
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 56
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 57
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 58
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 59
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 60
    if (line1 == 7 or line1 == 9) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 7 or line6 == 9):
        result = 61
    if (line1 == 6 or line1 == 8) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 6 or line6 == 8):
        result = 62
    if (line1 == 7 or line1 == 9) and (line2 == 6 or line2 == 8) and (line3 == 7 or line3 == 9) and (line4 == 6 or line4 == 8) and (line5 == 7 or line5 == 9) and (line6 == 6 or line6 == 8):
        result = 63
    if (line1 == 6 or line1 == 8) and (line2 == 7 or line2 == 9) and (line3 == 6 or line3 == 8) and (line4 == 7 or line4 == 9) and (line5 == 6 or line5 == 8) and (line6 == 7 or line6 == 9):
        result = 64
    # print('Result',result)
    return result

# iching()

# %%
# df.insert(2,'exa', iching(),True)
df['exa'] = df.apply(lambda x: iching(), axis = 1)
print(iching())
df[0:50]
# Out:
# 60
#           Date  VIX Open  VIX High  VIX Low  VIX Close  exa
# 0   2004-01-02     17.96     18.68    17.54      18.22   19
# 1   2004-01-05     18.45     18.49    17.44      17.49   35
# 2   2004-01-06     17.66     17.67    16.19      16.73   63
# 3   2004-01-07     16.72     16.75    15.50      15.50   23
# 4   2004-01-08     15.42     15.68    15.32      15.61    8
# 5   2004-01-09     16.15     16.88    15.57      16.75    1
# 6   2004-01-12     17.32     17.46    16.79      16.82   44
# 7   2004-01-13     16.60     18.33    16.53      18.04   36
# 8   2004-01-14     17.29     17.30    16.40      16.75   10
# 9   2004-01-15     17.07     17.31    15.49      15.56   30
# 10  2004-01-16     15.40     15.44    14.90      15.00   20
# 11  2004-01-20     15.77     16.13    15.09      15.21   17
# 12  2004-01-21     15.63     15.63    14.24      14.34   15
# 13  2004-01-22     14.20     14.87    14.01      14.71   41
# 14  2004-01-23     14.73     15.05    14.56      14.84   32
# ...

# %%
pd.set_option('display.max_rows', None)
df["exa"] = pd.to_numeric(df["exa"])
df = df.sort_values(by=['Date'], ascending=False)
df['delta'] = df['VIX Close'] - df['VIX Open']
df['volatile'] = df['VIX High'] - df['VIX Low']
df['bench_1'] =  df['delta'] / df['VIX Open'] * 100
df['bench_2'] =  df['volatile'] / df['VIX Open'] * 100
df[0:100]
# Out:
#             Date  VIX Open  VIX High  VIX Low  VIX Close  exa  delta  \
# 4198  2020-09-04     34.62     38.28    29.50      30.75   31  -3.87
# 4197  2020-09-03     26.28     35.94    25.66      33.60   38   7.32
# 4196  2020-09-02     26.01     27.07    25.53      26.57   43   0.56
# 4195  2020-09-01     25.86     26.59    25.02      26.12   46   0.26
# 4194  2020-08-31     23.91     26.50    21.77      26.41   33   2.50
# 4193  2020-08-28     24.59     26.30    22.64      22.96   63  -1.63
# 4192  2020-08-27     23.42     27.09    21.44      24.47   59   1.05
# 4191  2020-08-26     22.14     23.27    20.92      23.27   43   1.13
# 4190  2020-08-25     22.16     23.43    21.53      22.03   25  -0.13
# 4189  2020-08-24     22.87     23.18    21.25      22.37   53  -0.50
# 4188  2020-08-21     22.58     24.47    22.06      22.54   30  -0.04
# 4187  2020-08-20     24.10     24.60    22.37      22.72   20  -1.38
# 4186  2020-08-19     21.60     22.98    20.99      22.54   29   0.94
# ...
